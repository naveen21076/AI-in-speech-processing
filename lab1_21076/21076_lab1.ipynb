# %%
#pip install librosa

# %% [markdown]
# # M.NAVEEN KRISHNA AIE-21076 D-SEC

# %% [markdown]
# # A1. Load the recorded speech file into your python workspace. Once loaded, plot the graph for the speech signal

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
y, sr = librosa.load('naveen_lab1.wav')
plt.figure(figsize=(10, 5))
librosa.display.waveshow(y,color='black')
plt.title('Speech Signal Waveform')
plt.show()

# %% [markdown]
# # A2. Observe the length & magnitude range of the signal from the plot. Observing the plot, relate to the spoken words and silence between the words.

# %%
print("Length of the signal:",len(y),"samples")
print("Sampling rate:",sr, "Hz")
print("Magnitude range:",np.min(y),"to", np.max(y))
# Out:
# Length of the signal: 105840 samples
# Sampling rate: 22050 Hz
# Magnitude range: -0.20431396 to 0.23113464

# %% [markdown]
# # A3. Take a small segment of the signal and play it.

# %%
#diving the signal into segments
import IPython.display as ipd
start = int(0.6 * sr)
end = int(4.2 * sr)
segment = y[start:end]
librosa.display.waveshow(segment)
ipd.Audio(segment, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # A4. Play around with your recorded speech signal for various segments. Understand the nature of the signal. Also observe with abruptly segmented speech, how the perception of that speech is affected.

# %%
#diving the signal into 2 segments
segment_1_start = int(0 * sr)
segment_1_end = int(1.5 * sr)
segment_2_start = int(2 * sr)
segment_2_end = int(3.5 * sr)
segment_3_start = int(1 * sr)
segment_3_end = int(2.5 * sr)



segment_1 = y[segment_1_start:segment_1_end]
segment_2 = y[segment_2_start:segment_2_end]
segment_3 = y[segment_3_start:segment_3_end]

print("Playing Segment 1:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_1)
plt.title('Segment-1')
plt.show()
ipd.Audio(segment_1, rate=sr)
# Out:
# Playing Segment 1:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Playing Segment 2:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_2)
plt.title('Segment-2')
plt.show()
ipd.Audio(segment_2, rate=sr)
# Out:
# Playing Segment 2:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Playing Segment 3:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_3)
plt.title('Segment-3')
plt.show()
ipd.Audio(segment_3, rate=sr)
# Out:
# Playing Segment 3:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
